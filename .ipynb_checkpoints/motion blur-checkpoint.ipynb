# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
num = 18
frames = [];
for i in range(num):
    rgb = cv2.imread('frames/%d.png'%i)
    frames.append(rgb)

# %%
gray1 = cv2.imread('frames/7.png',0)

# %%
plt.imshow(frames[0], cmap = plt.cm.gray)
plt.show()

# %%
np.array(frames);

# %%
channel = 3
row = len(frames[0])
col = len(frames[0][0])

# %%
background = np.zeros((row,col,channel))

# %%
for i in range(row):
    for j in range(col):
        for l in range(channel):
            bg = []
            for k in range(num):
                bg.append(frames[k][i][j][l])
            np.array(bg)
            res = np.median(bg)
            background[i][j][l] = res

# %%
background = np.uint8(background)

# %%
plt.imshow(background)

# %%
object_1 = np.zeros((row,col))
object1 = frames[6]-background
threshold = np.max(frames[6]) - np.min(frames[6])
for i in range(row):
    for j in range(col):
        if np.abs(object1[i][j]) > 0.078*threshold:
            object_1[i][j] = frames[6][i][j] - background[i][j]
object_1 = np.uint8(object_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-13e87f0dc8ce> in <module>()
#       4 for i in range(row):
#       5     for j in range(col):
# ----> 6         if np.abs(object1[i][j]) > 0.078*threshold:
#       7             object_1[i][j] = frames[6][i][j] - background[i][j]
#       8 object_1 = np.uint8(object_1)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
object_2 = np.zeros((row,col))
object2 = frames[7]-background
threshold = np.max(frames[7]) - np.min(frames[7])
for i in range(row):
    for j in range(col):
        if np.abs(object2[i][j]) > 0.078*threshold:
            object_2[i][j] = frames[7][i][j] - background[i][j]
object_2 = np.uint8(object_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4f386963a12b> in <module>()
#       4 for i in range(row):
#       5     for j in range(col):
# ----> 6         if np.abs(object2[i][j]) > 0.078*threshold:
#       7             object_2[i][j] = frames[7][i][j] - background[i][j]
#       8 object_2 = np.uint8(object_2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.imshow(obj, cmap = plt.cm.gray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-df7529f5d1f6> in <module>()
# ----> 1 plt.imshow(obj, cmap = plt.cm.gray)
#
# NameError: name 'obj' is not defined

# %%
obj = np.zeros((row,col))
for i in range(row):
    for j in range(col):
        if (object_2[i][j]!=0):
            obj[i][j] = frames[7][i][j]
obj = np.uint8(obj)

# %%
img1 = cv2.imread('frames/7.png')              # img.shape : (413, 620, 3)
mask1 = np.zeros(img1.shape[:2],np.uint8)   # img.shape[:2] = (413, 620)
# img2 = cv2.imread('frame2.png')              # img.shape : (413, 620, 3)
# mask2 = np.zeros(img2.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

rect = (270,80,175,250)

# this modifies mask 
cv2.grabCut(img1,mask1,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

# If mask==2 or mask== 1, mask2 get 0, other wise it gets 1 as 'uint8' type.
mask2 = np.where((mask1==2)|(mask1==0),0,1).astype('uint8')

# adding additional dimension for rgb to the mask, by default it gets 1
# multiply it with input image to get the segmented image
img_cut = img1*mask2[:,:,np.newaxis]

plt.imshow(img1)

plt.imshow(img_cut)

# %%
print(np.max(mask2))
# Out:
# 1

# %%
size = 21
kernel = np.zeros((size,size))
kernel[int((size-1)/2.0),:] = np.ones(size)
kernel = kernel/size
output = cv2.filter2D(img_cut,-1,kernel)
plt.imshow(output, cmap = plt.cm.gray)

# %%
# print(kernel)
filterAll = cv2.filter2D(img1, -1, kernel)
filterAll = cv2.cvtColor(filterAll, cv2.COLOR_BGR2RGB)
plt.imshow(filterAll, cmap = plt.cm.gray)

# %%
img_cut_RGB = cv2.cvtColor(img_cut, cv2.COLOR_BGR2RGB)
output_RGB = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(output_RGB)

# %%
aimask = cv2.cvtColor(output_RGB, cv2.COLOR_RGB2GRAY)
plt.imshow(aimask, cmap=plt.cm.gray)
print(np.max(aimask))
# Out:
# 229

# %%
res = np.zeros((row,col,channel))
background = cv2.cvtColor(background, cv2.COLOR_BGR2RGB)
for i in range(row):
    for j in range(col):
        if aimask[i][j] > 0:
            res[i][j] = filterAll[i][j]
#         if aimask[i][j] > 0:
#             res[i][j] = background[i][j] * output_RGB[i][j]
        else:
            res[i][j] = background[i][j]
#         for k in range(channel):
#             if (output_RGB[i][j][k] == 0):
#                 res[i][j][k] = background[i][j][k]
#             else :
#                 res[i][j][k] = output_RGB[i][j][k]

# %%
res = np.uint8(res)

# %%
plt.imshow(res, cmap = plt.cm.gray)

# %%
Ik = img_cut_RGB
